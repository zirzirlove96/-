# %% [markdown]
# # 깊이우선 탐색과 너비우선 탐색

# %% [markdown]
# <pre>
# 깊이 우선 탐색(DFS)
# 현재 정점에서 한 방향으로 가면서 검사하기
# <b>막힌 정점은 포기하고 마지막에 따라온 간선으로 되돌아 간다.</b>
# </pre>

# %%
from IPython.display import Image
Image("C:/Users/ovokj/Desktop/DFS.PNG")

# %% [markdown]
# <pre>
# E->D->F->A->C->B
# STACK으로 인해 FILO(First In Last Out)
# 순회가 끝났다는 것은 stack이 비어있는 것으로 알 수 있다.
# </pre>

# %%
from IPython.display import Image
Image("C:/Users/ovokj/Desktop/BFS.PNG")

# %% [markdown]
# <pre>
# E->D->A->E->C->B
# QUEUE를 이용하여 FIFO(First In First Out)
# </pre>
