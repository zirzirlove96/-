# %% [markdown]
# <pre>
# Memoization
# Recursion(재귀)를 이용했을 때 과거에 많은 계산이 중복되는 경우가 많다.
# 이런 경우에 시간 초과가 걸릴 경우 <strong>이미 계산된 값을 기억해 놓는 것을 Memoization이라고 한다.</strong>
# 그 예를 들어 피보나치 수열이 있다.
# </pre>

# %%
from IPython.display import Image
Image("C:/Users/ovokj/Desktop/1.PNG")

# %% [markdown]
# <pre>
# Memoization을 사용하면 중복계산을 피할 수 있고
# 최대 값 구하기 등 을 할 수 있다.
# <strong>dp[i]=dp[i-1]+dp[i-2]</strong>
# 와 같이 나타내어 코드를 짤 수 있다.
# </pre>

# %%
from IPython.display import Image
Image("C:/Users/ovokj/Desktop/1.PNG")

# %%
from IPython.display import Image
Image("C:/Users/ovokj/Desktop/1.PNG")

# %% [markdown]
# <pre>
# return L[i][j]를 통해 저장된 값을 리턴할 수 있고
# if(L[i][j]!=-1) return L[i][j]
# 는 이미 저장된 값을 또 할 필요 없이 return 해 주는 것으로
# 중복된 계산을 하지 않아도 된다.
# </pre>
